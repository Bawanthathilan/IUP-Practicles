# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_raw = cv2.imread('apples.jpg', 1) #bgr
img = cv2.cvtColor(img_raw, cv2.COLOR_BGR2RGB) #rgb

img_neg = cv2.bitwise_not(img)

plt.imshow(img)
plt.show()

plt.imshow(img_neg)
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('apples.jpg', 0)
gamma = 0.6

img_2 = np.power(img,gamma)

plt.imshow(img, cmap='gray')
plt.show()

plt.imshow(img_2, cmap='gray')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('apples.jpg', 0)
gamma = 1.2

img_2 = np.power(img,gamma)

plt.imshow(img, cmap='gray')
plt.show()

plt.imshow(img_2, cmap='gray')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('apples.jpg', 0)

# Apply log trans method
c = 255/np.log(1+np.max(img))
log_img = c*(np.log(img+1))

# specify data type
# float converted to int
log_img = np.array(log_img, dtype = np.uint8)

plt.imshow(img, cmap='gray')
plt.show()

plt.imshow(log_img, cmap='gray')
plt.show()
# Out:
# <ipython-input-8-1e6cf148d2da>:9: RuntimeWarning: divide by zero encountered in log
#   log_img = c*(np.log(img+1))
